# %%
import pandas as pd

# %%
dataset=pd.read_csv('insurance_pre.csv')
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
#from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.model_selection import GridSearchCV
#from sklearn.tree import DecisionTreeRegressor
param_grid = {
    
     'max_depth': [5, 7],
    'min_samples_split': [ 5, 10],
    'min_samples_leaf': [1,2, 4]
}

#param_grid={
    
 #   'n_estimators': [100, 200],
#    'max_features': ['auto', 'sqrt','log2'],
#    'max_depth': [10, 20],
#    'min_samples_leaf': [1,2, 4],
 #   'min_samples_split': [5, 10]
    
#}
#'min_samples_leaf': [1, 2, 4],
 #   'bootstrap': [True, False]
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)

# fitting the model for grid search
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [5, 7], 'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [5, 10]},
#              verbose=3)

# %%
re=grid.cv_results_
#print(re)
print("The R_score value for best parameter {}:".format(grid.best_params_))
print("Best R^2 score:", grid.best_score_)
#print("The best r_score",r_score)
# Out:
# The R_score value for best parameter {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 5}:
# Best R^2 score: 0.8482064687681768

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.011886      0.004504         0.003714        0.002159
# 1       0.010090      0.004012         0.004469        0.002693
# 2       0.007081      0.001642         0.004401        0.000841
# 3       0.002001      0.004002         0.007694        0.005449
# 4       0.007068      0.008293         0.006584        0.006004
# 5       0.010507      0.001809         0.001622        0.001682
# 6       0.006681      0.003969         0.004842        0.005084
# 7       0.005849      0.005649         0.000953        0.001167
#
#   param_max_depth param_min_samples_leaf param_min_samples_split  \
# 0               5                      2                       5
# 1               5                      2                      10
# 2               5                      4                       5
# 3               5                      4                      10
# ...

# %%
import pickle
filename='finalized_model_MLAssignment_DT_GridSearchCVWithoutTrain&Test.sav'
pickle.dump(grid,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('finalized_model_MLAssignment_DT_GridSearchCVWithoutTrain&Test.sav','rb'))
result=loaded_model.predict([[50,27.970,0,1,0]])
result
# Out:
# C:\AI\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([11060.90845546])
