# %%
import pandas as pd

# %%
dataset=pd.read_csv('insurance_pre.csv')
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0     False        True
# 1      18  33.770         1      True       False
# 2      28  33.000         3      True       False
# 3      33  22.705         0      True       False
# 4      32  28.880         0      True       False
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3      True       False
# 1334   18  31.920         0     False       False
# 1335   18  36.850         0     False       False
# 1336   21  25.800         0     False       False
# 1337   61  29.070         0     False        True
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
#from sklearn.tree import DecisionTreeRegressor
#param_grid = {'criterion':['mse','mae'],
#'max_features': ['auto','sqrt','log2'],
#'n_estimators':[10,100]}

param_grid={
    
    'n_estimators': [100, 200],
    'max_features': ['auto', 'sqrt','log2'],
    'max_depth': [10, 20],
    'min_samples_leaf': [1,2, 4],
    'min_samples_split': [5, 10]
    
}
#'min_samples_leaf': [1, 2, 4],
 #   'bootstrap': [True, False]
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)

# fitting the model for grid search
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# C:\AI\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 120 fits failed out of a total of 360.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 47 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\AI\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\AI\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\AI\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\AI\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 73 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\AI\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\AI\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\AI\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "C:\AI\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\AI\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.8449383  0.84609884 0.84741109 0.84740354 0.84753638 0.84648814
#  0.84763092 0.84831251 0.84813567 0.84789449 0.84759835 0.84922526
#  0.84411654 0.84583789 0.84655883 0.84764843 0.84593319 0.84709274
#  0.84809338 0.84860408 0.8458818  0.85029657 0.84704605 0.84821956
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.84128436 0.84256485 0.84702006 0.84633981 0.84597394 0.8460299
#  0.8471026  0.84763775 0.84651974 0.8482909  0.84783221 0.8481693
#  0.84229957 0.84320022 0.84449018 0.84730131 0.84549607 0.84708909
#  0.84632653 0.84891005 0.84872995 0.8488461  0.84886402 0.84688271]
#   warnings.warn(
# C:\AI\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [10, 20],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [5, 10],
#                          'n_estimators': [100, 200]},
#              verbose=3)

# %%
re=grid.cv_results_
#print(re)
print("The R_score value for best parameter {}:".format(grid.best_params_))
print("Best R^2 score:", grid.best_score_)
#print("The best r_score",r_score)
# Out:
# The R_score value for best parameter {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 200}:
# Best R^2 score: 0.8498661282978599

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.003025      0.000716         0.000000        0.000000
# 1        0.003130      0.003863         0.000000        0.000000
# 2        0.003021      0.003711         0.000000        0.000000
# 3        0.001622      0.003243         0.000000        0.000000
# 4        0.003127      0.006253         0.000000        0.000000
# 5        0.006253      0.007658         0.000000        0.000000
# 6        0.000000      0.000000         0.000000        0.000000
# 7        0.006304      0.007721         0.000000        0.000000
# 8        0.002402      0.004805         0.000000        0.000000
# 9        0.006366      0.007797         0.000000        0.000000
# 10       0.002349      0.001960         0.000000        0.000000
# 11       0.004351      0.003657         0.000000        0.000000
# 12       1.202335      0.056391         0.063193        0.015513
# 13       2.346438      0.111490         0.102355        0.009815
# 14       1.123926      0.109871         0.047284        0.003210
# 15       2.258808      0.140118         0.101951        0.017630
# 16       1.277896      0.088661         0.059072        0.004730
# 17       2.330327      0.133832         0.103887        0.008251
# 18       1.092210      0.131563         0.053542        0.010399
# 19       1.979246      0.053156         0.105270        0.019004
# 20       1.100469      0.113163         0.053239        0.012033
# 21       2.109427      0.083825         0.088199        0.008385
# 22       1.062017      0.096695         0.051877        0.011968
# 23       2.051426      0.108806         0.092923        0.014190
# 24       0.004082      0.003949         0.000000        0.000000
# 25       0.003050      0.004031         0.000000        0.000000
# 26       0.001061      0.001500         0.000000        0.000000
# 27       0.001679      0.003359         0.000000        0.000000
# 28       0.003153      0.004038         0.000000        0.000000
# 29       0.003806      0.006940         0.000000        0.000000
# 30       0.003220      0.006441         0.000000        0.000000
# 31       0.006209      0.007611         0.000000        0.000000
# 32       0.001403      0.002805         0.000000        0.000000
# 33       0.003522      0.006103         0.000000        0.000000
# 34       0.004460      0.006152         0.000000        0.000000
# 35       0.005730      0.007066         0.000000        0.000000
# 36       1.369728      0.050165         0.059489        0.010536
# 37       2.626268      0.110589         0.103677        0.006478
# 38       1.006698      0.035556         0.047873        0.010279
# 39       2.183198      0.112767         0.096566        0.004265
# 40       1.299455      0.106016         0.053070        0.009066
# 41       2.612353      0.177202         0.093278        0.005852
# 42       1.132563      0.136506         0.049299        0.012100
# 43       2.057297      0.168660         0.085631        0.006649
# 44       0.946825      0.030878         0.044912        0.006814
# 45       2.016081      0.170868         0.097140        0.017148
# 46       0.937473      0.116323         0.044660        0.009694
# 47       1.833605      0.194093         0.078529        0.007869
#
#    param_max_depth param_max_features param_min_samples_leaf  \
# 0               10               auto                      1
# 1               10               auto                      1
# 2               10               auto                      1
# 3               10               auto                      1
# 4               10               auto                      2
# 5               10               auto                      2
# 6               10               auto                      2
# 7               10               auto                      2
# 8               10               auto                      4
# 9               10               auto                      4
# 10              10               auto                      4
# 11              10               auto                      4
# 12              10               sqrt                      1
# 13              10               sqrt                      1
# 14              10               sqrt                      1
# 15              10               sqrt                      1
# 16              10               sqrt                      2
# 17              10               sqrt                      2
# 18              10               sqrt                      2
# 19              10               sqrt                      2
# 20              10               sqrt                      4
# 21              10               sqrt                      4
# 22              10               sqrt                      4
# 23              10               sqrt                      4
# 24              20               auto                      1
# 25              20               auto                      1
# 26              20               auto                      1
# 27              20               auto                      1
# 28              20               auto                      2
# 29              20               auto                      2
# 30              20               auto                      2
# 31              20               auto                      2
# 32              20               auto                      4
# 33              20               auto                      4
# 34              20               auto                      4
# 35              20               auto                      4
# 36              20               sqrt                      1
# 37              20               sqrt                      1
# 38              20               sqrt                      1
# 39              20               sqrt                      1
# 40              20               sqrt                      2
# 41              20               sqrt                      2
# 42              20               sqrt                      2
# 43              20               sqrt                      2
# 44              20               sqrt                      4
# 45              20               sqrt                      4
# 46              20               sqrt                      4
# 47              20               sqrt                      4
#
#    param_min_samples_split param_n_estimators  \
# 0                        5                100
# 1                        5                200
# 2                       10                100
# 3                       10                200
# 4                        5                100
# 5                        5                200
# 6                       10                100
# 7                       10                200
# 8                        5                100
# 9                        5                200
# 10                      10                100
# 11                      10                200
# 12                       5                100
# 13                       5                200
# 14                      10                100
# 15                      10                200
# 16                       5                100
# 17                       5                200
# 18                      10                100
# 19                      10                200
# 20                       5                100
# 21                       5                200
# 22                      10                100
# 23                      10                200
# 24                       5                100
# 25                       5                200
# 26                      10                100
# 27                      10                200
# 28                       5                100
# 29                       5                200
# 30                      10                100
# 31                      10                200
# 32                       5                100
# 33                       5                200
# 34                      10                100
# 35                      10                200
# 36                       5                100
# 37                       5                200
# 38                      10                100
# 39                      10                200
# 40                       5                100
# 41                       5                200
# 42                      10                100
# 43                      10                200
# 44                       5                100
# 45                       5                200
# 46                      10                100
# 47                      10                200
#
#                                                params  split0_test_score  \
# 0   {'max_depth': 10, 'max_features': 'auto', 'min...                NaN
# 1   {'max_depth': 10, 'max_features': 'auto', 'min...                NaN
# 2   {'max_depth': 10, 'max_features': 'auto', 'min...                NaN
# 3   {'max_depth': 10, 'max_features': 'auto', 'min...                NaN
# 4   {'max_depth': 10, 'max_features': 'auto', 'min...                NaN
# 5   {'max_depth': 10, 'max_features': 'auto', 'min...                NaN
# 6   {'max_depth': 10, 'max_features': 'auto', 'min...                NaN
# 7   {'max_depth': 10, 'max_features': 'auto', 'min...                NaN
# 8   {'max_depth': 10, 'max_features': 'auto', 'min...                NaN
# 9   {'max_depth': 10, 'max_features': 'auto', 'min...                NaN
# 10  {'max_depth': 10, 'max_features': 'auto', 'min...                NaN
# 11  {'max_depth': 10, 'max_features': 'auto', 'min...                NaN
# 12  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.872065
# 13  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.868288
# 14  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.872795
# 15  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.871267
# 16  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.874076
# 17  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.873819
# 18  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.871893
# 19  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.873733
# 20  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.872050
# 21  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.875663
# 22  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.872937
# 23  {'max_depth': 10, 'max_features': 'sqrt', 'min...           0.873831
# 24  {'max_depth': 20, 'max_features': 'auto', 'min...                NaN
# 25  {'max_depth': 20, 'max_features': 'auto', 'min...                NaN
# 26  {'max_depth': 20, 'max_features': 'auto', 'min...                NaN
# 27  {'max_depth': 20, 'max_features': 'auto', 'min...                NaN
# 28  {'max_depth': 20, 'max_features': 'auto', 'min...                NaN
# 29  {'max_depth': 20, 'max_features': 'auto', 'min...                NaN
# 30  {'max_depth': 20, 'max_features': 'auto', 'min...                NaN
# 31  {'max_depth': 20, 'max_features': 'auto', 'min...                NaN
# 32  {'max_depth': 20, 'max_features': 'auto', 'min...                NaN
# 33  {'max_depth': 20, 'max_features': 'auto', 'min...                NaN
# 34  {'max_depth': 20, 'max_features': 'auto', 'min...                NaN
# 35  {'max_depth': 20, 'max_features': 'auto', 'min...                NaN
# 36  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.868599
# 37  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.866063
# 38  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.868810
# 39  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.872142
# 40  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.871446
# 41  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.871064
# 42  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.873683
# 43  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.873270
# 44  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.875166
# 45  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.876089
# 46  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.875745
# 47  {'max_depth': 20, 'max_features': 'sqrt', 'min...           0.873505
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8                 NaN                NaN                NaN
# 9                 NaN                NaN                NaN
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12           0.791733           0.873325           0.836084
# 13           0.791743           0.873142           0.837513
# 14           0.797122           0.874004           0.836220
# 15           0.797389           0.873799           0.840298
# 16           0.796264           0.872066           0.839432
# 17           0.798541           0.877332           0.838631
# 18           0.799338           0.877108           0.839540
# 19           0.800067           0.872218           0.840068
# 20           0.802458           0.875293           0.840396
# 21           0.801932           0.874546           0.840182
# 22           0.798704           0.879550           0.840182
# 23           0.802924           0.873789           0.839703
# 24                NaN                NaN                NaN
# 25                NaN                NaN                NaN
# 26                NaN                NaN                NaN
# 27                NaN                NaN                NaN
# 28                NaN                NaN                NaN
# 29                NaN                NaN                NaN
# 30                NaN                NaN                NaN
# 31                NaN                NaN                NaN
# 32                NaN                NaN                NaN
# 33                NaN                NaN                NaN
# 34                NaN                NaN                NaN
# 35                NaN                NaN                NaN
# 36           0.787763           0.870423           0.835591
# 37           0.790304           0.870208           0.834659
# 38           0.795716           0.874853           0.836397
# 39           0.797348           0.872446           0.839168
# 40           0.795511           0.874065           0.837474
# 41           0.796529           0.875042           0.833946
# 42           0.797218           0.867514           0.838563
# 43           0.797658           0.872895           0.839098
# 44           0.799715           0.870056           0.839990
# 45           0.802492           0.874741           0.839802
# 46           0.802491           0.865367           0.841462
# 47           0.802409           0.874542           0.840359
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               25
# 1                 NaN              NaN             NaN               25
# 2                 NaN              NaN             NaN               25
# 3                 NaN              NaN             NaN               25
# 4                 NaN              NaN             NaN               25
# 5                 NaN              NaN             NaN               25
# 6                 NaN              NaN             NaN               25
# 7                 NaN              NaN             NaN               25
# 8                 NaN              NaN             NaN               25
# 9                 NaN              NaN             NaN               25
# 10                NaN              NaN             NaN               25
# 11                NaN              NaN             NaN               25
# 12           0.853004         0.845242        0.030051               21
# 13           0.854392         0.845015        0.029377               22
# 14           0.855234         0.847075        0.028518               14
# 15           0.855413         0.847633        0.027864               11
# 16           0.853530         0.847074        0.028409               15
# 17           0.852749         0.848214        0.028577                9
# 18           0.853510         0.848278        0.027884                8
# 19           0.857167         0.848651        0.027170                6
# 20           0.856037         0.849247        0.026503                4
# 21           0.857008         0.849866        0.027266                1
# 22           0.851193         0.848513        0.028696                7
# 23           0.856977         0.849445        0.026469                3
# 24                NaN              NaN             NaN               25
# 25                NaN              NaN             NaN               25
# 26                NaN              NaN             NaN               25
# 27                NaN              NaN             NaN               25
# 28                NaN              NaN             NaN               25
# 29                NaN              NaN             NaN               25
# 30                NaN              NaN             NaN               25
# 31                NaN              NaN             NaN               25
# 32                NaN              NaN             NaN               25
# 33                NaN              NaN             NaN               25
# 34                NaN              NaN             NaN               25
# 35                NaN              NaN             NaN               25
# 36           0.846804         0.841836        0.030070               23
# 37           0.847862         0.841819        0.028758               24
# 38           0.853430         0.845841        0.028385               20
# 39           0.854246         0.847070        0.027780               16
# 40           0.851551         0.846010        0.028593               19
# 41           0.855668         0.846450        0.028833               18
# 42           0.857786         0.846953        0.027563               17
# 43           0.854075         0.847399        0.027954               13
# 44           0.853020         0.847589        0.026998               12
# 45           0.855576         0.849740        0.027146                2
# 46           0.853297         0.847672        0.025348               10
# 47           0.854705         0.849104        0.026574                5

# %%
import pickle
filename='finalized_model_MLAssignment_RandomForest_GridSearchCVWithoutTrain&Test.sav'
pickle.dump(grid,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('finalized_model_MLAssignment_RandomForest_GridSearchCVWithoutTrain&Test.sav','rb'))
result=loaded_model.predict([[50,27.970,0,1,0]])
result
# Out:
# C:\AI\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([11434.57916333])
